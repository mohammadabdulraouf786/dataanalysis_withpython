# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadabdulraouf786/dataanalysis_withpython/blob/main/DA_DAY5_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
page=requests.get('https://randomfox.ca/floof')

# %%
print(page.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/2.jpg","link":"https:\/\/randomfox.ca\/?i=2"}

# %%
print(page.json())
# Out:
# {'image': 'https://randomfox.ca/images/2.jpg', 'link': 'https://randomfox.ca/?i=2'}
# {'image': 'https://randomfox.ca/images/2.jpg', 'link': 'https://randomfox.ca/?i=2'}

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '775d2d11-1f4f-4466-86cb-67c4809d1eb1',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-02-16T09:44:39.708Z', 'error_code': 0, 'error_message': None, 'elapsed': 2, 'credit_count': 1, 'notice': None}, 'data': [{'id': 2453, 'name': 'bkis3yf74cn', 'symbol': 'wk9t93jy84', 'slug': 'xl919mvfr2', 'cmc_rank': 510, 'num_market_pairs': 896, 'circulating_supply': 3156, 'total_supply': 5139, 'max_supply': 8533, 'infinite_supply': None, 'last_updated': '2024-02-16T09:44:39.707Z', 'date_added': '2024-02-16T09:44:39.707Z', 'tags': ['54o0mq5bod6', 'ituhiw5ymb', 'e4trbj5p1oi', 'dlf0wa28run', 'ozppvofw7a', '9v2ebuhsxn', 'kvte88shc3p', 'u26nnze9i', '883awgzjfpi', 'm5f2hy91la'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.8519017689651565, 'volume_24h': 4508, 'volume_change_24h': 0.3929941420966121, 'percent_change_1h': 0.14312424667176615, 'percent_change_24h': 0.48766735053400767, 'percent_change_7d': 0.9017122679556397, 'market_cap': 0.5503479348891323, 'market_cap_dominance': 4
# ...

# %%
import pandas as pd
norm=pd.json_normalize(data['data'])

# %%
norm
# Out:
#      id          name        symbol         slug  cmc_rank  num_market_pairs  \
# 0  2453   bkis3yf74cn    wk9t93jy84   xl919mvfr2       510               896
# 1  9219  0hsftrw8jj7j    qe1nz43ex8  la2p8aznbij      7405              4976
# 2  4231   xn74z0ao7tr   kvc39m1fc8b   c05ibqx4cs      4798              4159
# 3  2418   e38hwj4f3cb  0hw3f8f0be69  h80e3zk08id      7788              9968
# 4  1683   nmf5er4rdqc   rhz75274u2c  th9jtnhna1f      7926               828
# 5  6753    x4mecm9g78   3tnzwim4pm4  lsz9wta3wxg      4203              4049
# 6  3139   botlnqwm47i    ilqe9uq8xe   xd6i1mma5b      5426              5539
# 7  1470   jbrt3du58tp   cel0z4xgs4r  ajaojtd232t      6939              3974
# 8  1594   1uui3n8n6hn   7bsrtelx037   20144s1cs7      1497              1326
# 9   977   vy4xm79vggm   7qv7dyat4i5  8vswuk8cej3      4358              9513
#
#    circulating_supply  total_supply  max_supply infinite_supply  ...  \
# ...
